# %%
import pandas as pd
import numpy as np
import networkx as nx

import os
import shutil
# Set up paths
PYTHONPATH = "/global/homes/b/bpb/repos/envnet"
os.environ['PYTHONPATH'] = PYTHONPATH

# Import ENVnet
import sys
sys.path.insert(0, PYTHONPATH)
from envnet.build import quick_envnet
from envnet.config.build_config import BuildConfig
from envnet.build import ENVnetBuilder
from envnet.build.mgf_tools import MGFGenerator
config = BuildConfig()
mgf_generator = MGFGenerator(config)

# %%
# use recursive find to get all parquet files
# use linux find since it is much faster than glob
cmd = "find /global/cfs/cdirs/metatlas/projects/envnet_build_files/ -name '*_deconvoluted.parquet'"
# run command
import subprocess
result = subprocess.run(cmd, shell=True, capture_output=True, text=True)
files = result.stdout.splitlines()
len(files)
# Out:
# 1401

# %%
file_df = pd.DataFrame(files, columns=['parquet_file'])
file_df.reset_index(drop=False, inplace=True)
file_df.to_csv('/global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon.csv',index=False)

# %%
# BEGIN IONS
# TITLE=mzspec:USI000000:61_Sammy:scan:Id=503572
# PEPMASS=105.066146850586
# RTINSECONDS=8.392733333333
# CHARGE=1+
# CLUSTER=0
# 50.00249 0.0
# 50.00372 16.0

# %%
output_dir = '/global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon'

def modify_file_for_falcon(filename):
    with open(filename,'r') as fid:
        mgf_text = fid.read()

    replace_text = 'FEATURE_ID='
    new_text = 'TITLE=%s:'%filename
    mgf_text = mgf_text.replace(replace_text, new_text)

    replace_text = 'ORIGINAL_ID='
    new_text = 'CLUSTER='
    mgf_text = mgf_text.replace(replace_text, new_text)

    with open(filename,'w') as fid:
        fid.write(mgf_text)

def make_mgf_helper(temp_df):
    network = nx.Graph()
    network.add_nodes_from(temp_df['original_index'].to_list())
    created_files = mgf_generator.create_mgf_files(
        node_data=temp_df,
        network=network,
        output_dir=str(output_dir)
    )
    return created_files

df = []
my_cols = ['precursor_mz','rt','original_spectrum_mz_vals','original_spectrum_intensity_vals','deconvoluted_spectrum_mz_vals','deconvoluted_spectrum_intensity_vals']
for i,row in file_df.iterrows():
    parquet_file = row['parquet_file']
    old_filename = '/global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf'
    new_filename = old_filename.replace('envnet_deconvoluted_spectra.mgf','file_%d.mgf'%row['index'])
    if os.path.exists(new_filename):
        continue
    temp_df = pd.read_parquet(parquet_file,columns=my_cols)
    temp_df.index.name = 'original_index'
    temp_df = temp_df.reset_index()
    created_files = make_mgf_helper(temp_df)
    # move the file
    shutil.move(old_filename, new_filename)
    modify_file_for_falcon(new_filename)

# change the group ownership recursively
cmd = ["chgrp", "-R", 'metatlas', str(output_dir)]
result = subprocess.run(cmd, check=True, capture_output=True, text=True)

file_to_delete = created_files['original']
os.remove(file_to_delete)
# Out:
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1079 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1079 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1736 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1736 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1434 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1434 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1495 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1495 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2683 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2683 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1188 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1188 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1337 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1337 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 864 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 864 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1620 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1620 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1024 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1024 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 890 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 890 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 545 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 545 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1552 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1552 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1872 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1872 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 925 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 925 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1172 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1172 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 293 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 293 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1247 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1247 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 3142 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 3142 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1229 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1229 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 878 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 878 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1698 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1698 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1006 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1006 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2892 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2892 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 915 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 915 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1359 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1359 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 659 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 659 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1745 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1745 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1432 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1432 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2065 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2065 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1171 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1171 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1473 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1473 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 834 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 834 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1146 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1146 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1354 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1354 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 494 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 494 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1008 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1008 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1132 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1132 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2185 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2185 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 3165 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 3165 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2294 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2294 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1196 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1196 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1027 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1027 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1010 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1010 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 3014 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 3014 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 977 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 977 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2997 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2997 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1128 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1128 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 859 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 859 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2106 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2106 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1088 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1088 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2407 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2407 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1648 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1648 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 686 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 686 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2664 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2664 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1477 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1477 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1028 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1028 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 935 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 935 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 668 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 668 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1227 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1227 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1147 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1147 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 412 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 412 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 546 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 546 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1872 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1872 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2925 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2925 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1115 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1115 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 244 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 244 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 997 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 997 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1549 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1549 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 3131 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 3131 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1751 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1751 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1593 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1593 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1026 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1026 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1096 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1096 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2935 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2935 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 892 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 892 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1029 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1029 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1185 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1185 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 857 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 857 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 654 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 654 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1005 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1005 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 953 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 953 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1885 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1885 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1877 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1877 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1229 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1229 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1048 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1048 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1825 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1825 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 933 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 933 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1039 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1039 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1013 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1013 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2271 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2271 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1411 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1411 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1005 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1005 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 866 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 866 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1403 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1403 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1250 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1250 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2972 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2972 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1707 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1707 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2623 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2623 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2088 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2088 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1008 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1008 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1316 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1316 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1510 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1510 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1660 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1660 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1918 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1918 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 239 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 239 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1590 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1590 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 845 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 845 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 975 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 975 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1382 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1382 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 987 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 987 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 787 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 787 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1032 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1032 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1127 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1127 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1332 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1332 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 393 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 393 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1809 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1809 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 534 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 534 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 944 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 944 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2477 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2477 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1042 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1042 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 4602 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 4602 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1718 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1718 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 572 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 572 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 962 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 962 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 3260 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 3260 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 4073 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 4073 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 718 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 718 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1008 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1008 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 999 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 999 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1560 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1560 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1209 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1209 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 774 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 774 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 884 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 884 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1485 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1485 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 219 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 219 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1151 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1151 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 707 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 707 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1481 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1481 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1696 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1696 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1407 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1407 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2756 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2756 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 956 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 956 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 810 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 810 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1286 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1286 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 865 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 865 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 530 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 530 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1106 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1106 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 4202 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 4202 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1054 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1054 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 900 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 900 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1307 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1307 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1620 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1620 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 708 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 708 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 952 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 952 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2177 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2177 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1426 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1426 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1362 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1362 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1041 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1041 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1164 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1164 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2739 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2739 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1254 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1254 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2983 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2983 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1359 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1359 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 3952 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 3952 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2355 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2355 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 852 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 852 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1046 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1046 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 796 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 796 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 951 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 951 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1191 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1191 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1557 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1557 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1593 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1593 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1178 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1178 spectra
# ...
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 5352 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 5352 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 118 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 118 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 3923 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 3923 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 4882 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 4882 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2020 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2020 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 127 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 127 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2346 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2346 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1019 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1019 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 95 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 95 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 240 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 240 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 4708 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 4708 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2930 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2930 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 148 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 148 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 160 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 160 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2005 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2005 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2682 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2682 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1128 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1128 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 5051 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 5051 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1612 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1612 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2515 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2515 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1521 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1521 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 103 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 103 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 5297 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 5297 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 515 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 515 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 108 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 108 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 4983 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 4983 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 325 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 325 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 3017 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 3017 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 5281 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 5281 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 4818 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 4818 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 65 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 65 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1058 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1058 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 905 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 905 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 287 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 287 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 4425 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 4425 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1664 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1664 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 399 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 399 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 5033 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 5033 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1259 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1259 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2385 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2385 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 5342 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 5342 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2477 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2477 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 81 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 81 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 5267 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 5267 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2846 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2846 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 5260 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 5260 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 950 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 950 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 4441 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 4441 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 5237 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 5237 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 5343 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 5343 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 4756 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 4756 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 5158 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 5158 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 472 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 472 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1778 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1778 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1617 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1617 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 1993 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 1993 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 2395 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 2395 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_deconvoluted_spectra.mgf with 711 spectra
# Created MGF file: /global/cfs/cdirs/metatlas/projects/carbon_network/mgf_files_for_falcon/envnet_original_spectra.mgf with 711 spectra

# %%
row['parquet_file']
# Out:
# '/global/cfs/cdirs/metatlas/projects/envnet_build_files/metatlas/20230403_EB_BGS_107002-011_BIODESERT_Metagenome_EXP120A_C18-EP_USDAY72349_NEG_MS2_116_KEN-Wamiti-Kalama-1PLH-2GZM_1__288_deconvoluted.parquet'

# %%
# change the folder to be read/write by metatlas group
