# %%
import os
import subprocess
import pandas as pd

# %%
cmd = "find /global/cfs/cdirs/metatlas/projects/envnet_build_files -name '*.h5'"
result = subprocess.run(cmd, shell=True, capture_output=True, text=True)
files = result.stdout.splitlines()
len(files)
# Out:
# 1886

# %%
import os
files_to_convert = []
for f in files:
    parquet_filename = f.replace(".h5", "_deconvoluted.parquet")
    
    if not os.path.exists(parquet_filename):
        files_to_convert.append(f)
len(files_to_convert)
# Out:
# 485

# %%
sbatch_header = """#!/bin/bash
#SBATCH --job-name="DOM_Interlab-LCMS_Lab018_M_Neg_MS2_rep2"
#SBATCH --output="/pscratch/sd/b/bpb/metatlas_mdm_parquet_files/DOM_Interlab-LCMS_Lab018_M_Neg_MS2_rep2.out"
#SBATCH --error="/pscratch/sd/b/bpb/metatlas_mdm_parquet_files/DOM_Interlab-LCMS_Lab018_M_Neg_MS2_rep2.err"
#SBATCH --time=08:00:00
#SBATCH --qos=regular
#SBATCH --ntasks-per-node=128
#SBATCH --licenses=cfs
#SBATCH --exclusive
#SBATCH --constraint=cpu
#SBATCH --nodes=1
#SBATCH --cpus-per-task=1
#SBATCH --account=m2650

export PYTHONPATH=/global/homes/b/bpb/repos/envnet

"""

commands = []
python_binary = '/global/common/software/m2650/msbuddy/bin/python'
python_command = '-m envnet.deconvolution.workflows --do_buddy'
for f in files_to_convert:
    commands.append('%s %s "%s"' % (python_binary, python_command, f))

# split commands into 7 chunks
chunk_size = 200
command_chunks = [commands[i:i + chunk_size] for i in range(0, len(commands), chunk_size)]
launch_dir = '/pscratch/sd/b/bpb/metatlas_mdm_parquet_files'
sbatch_files = []
for i, chunk in enumerate(command_chunks):
    sbatch_file = os.path.join(launch_dir, f"sbatch_chunk_{i}.sbatch")
    with open(sbatch_file, 'w') as f:
        f.write(sbatch_header)
        f.write("\n".join(chunk))
    sbatch_files.append(sbatch_file)

with open(os.path.join(launch_dir, "submit_all_sbatch.sh"), 'w') as f:
    f.write("#!/bin/bash\n")
    for sbatch_file in sbatch_files:
        f.write(f"sbatch {sbatch_file}\n")

# %%
new_file = '/global/cfs/cdirs/metatlas/projects/envnet_build_files/metatlas/20230403_EB_BGS_107002-011_BIODESERT_Metagenome_EXP120A_C18-EP_USDAY72349_NEG_MS2_84_HUN-Valk-Nagyivan-1PLH-2GZM_1__623_deconvoluted.parquet'
old_file = '/global/cfs/cdirs/metatlas/projects/carbon_network/raw_data/metatlas/20230403_EB_BGS_107002-011_BIODESERT_Metagenome_EXP120A_C18-EP_USDAY72349_NEG_MS2_84_HUN-Valk-Nagyivan-1PLH-2GZM_1__623_deconvoluted.parquet'
new_df = pd.read_parquet(new_file)
old_df = pd.read_parquet(old_file)
new_df.shape,old_df.shape
# Out:
# ((1698, 19), (1500, 19))

# %%
new_df.sort_values('coisolated_precursor_count',ascending=False).head(10)
# Out:
#       temp_index        rt  count  precursor_mz  sum_frag_intensity  \
# 1043        1043  3.858191      4    343.214015        44900.896729
# 1112        1112  3.976118      4    301.128843        28275.557129
# 1040        1040  3.858191      6    343.103486        51416.438232
# 1041        1041  3.858191      4    343.140070        13666.897949
# 1042        1042  3.858191      4    343.176265        14713.614990
# 585          585  2.925540      3    225.112802        29017.872681
# 1188        1188  4.120216      3    341.087702        30332.703857
# 1190        1190  4.120216      6    341.160102        14431.778809
# 1584        1584  4.918899      5    327.217933       180084.198242
# 1191        1191  4.120216      4    341.197237        78454.046875
#
#       max_frag_intensity                                                obs  \
# 1043        28929.775391                          [C2H4O, CO2, 2x H2O, H2O]
# 1112        10119.420898      [2x CO2 + CO, 2x CO2 + H2O, 2x CO2, CO2 + CO]
# 1040        22295.535156  [3x CO2 + H2O + CO, 3x CO2 + CH4, 2x CO2 + H2O...
# 1041         5211.439941  [3x CO2 + CH4, 2x CO2 + CH4O, 2x CO2 + H2O, 2x...
# 1042         4917.296387                [CO2 + CH4O, C4H4O, CO2 + H2O, H2O]
# 585         23874.125000                                 [C4H4O, CO2, C2H4]
# 1188        24066.441406          [4x CO2 + CH4, 3x CO2 + H2O + CO, 3x CO2]
# 1190         3314.373291  [2x CO2 + H2O, 2x CO2, CO2 + CH4O, CO2 + H2O, ...
# 1584        98826.671875               [CO2 + H2O, C2H4O, CO2, 2x H2O, H2O]
# 1191        40226.183594                      [CO2 + H2O, CO2, 2x H2O, H2O]
#
#       isolated_precursor_mz  \
# 1043             343.212097
# 1112             301.201813
# 1040             343.212097
# 1041             343.212097
# 1042             343.212097
# 585              225.074081
# 1188             341.196320
# 1190             341.196320
# 1584             327.217346
# 1191             341.196320
#
#                                                filename  \
# 1043  /global/cfs/cdirs/metatlas/projects/envnet_bui...
# 1112  /global/cfs/cdirs/metatlas/projects/envnet_bui...
# 1040  /global/cfs/cdirs/metatlas/projects/envnet_bui...
# 1041  /global/cfs/cdirs/metatlas/projects/envnet_bui...
# 1042  /global/cfs/cdirs/metatlas/projects/envnet_bui...
# 585   /global/cfs/cdirs/metatlas/projects/envnet_bui...
# 1188  /global/cfs/cdirs/metatlas/projects/envnet_bui...
# 1190  /global/cfs/cdirs/metatlas/projects/envnet_bui...
# 1584  /global/cfs/cdirs/metatlas/projects/envnet_bui...
# 1191  /global/cfs/cdirs/metatlas/projects/envnet_bui...
#
#                                                basename  \
# 1043  20230403_EB_BGS_107002-011_BIODESERT_Metagenom...
# 1112  20230403_EB_BGS_107002-011_BIODESERT_Metagenom...
# 1040  20230403_EB_BGS_107002-011_BIODESERT_Metagenom...
# 1041  20230403_EB_BGS_107002-011_BIODESERT_Metagenom...
# 1042  20230403_EB_BGS_107002-011_BIODESERT_Metagenom...
# 585   20230403_EB_BGS_107002-011_BIODESERT_Metagenom...
# 1188  20230403_EB_BGS_107002-011_BIODESERT_Metagenom...
# 1190  20230403_EB_BGS_107002-011_BIODESERT_Metagenom...
# 1584  20230403_EB_BGS_107002-011_BIODESERT_Metagenom...
# 1191  20230403_EB_BGS_107002-011_BIODESERT_Metagenom...
#
#       coisolated_precursor_count  \
# 1043                           5
# 1112                           5
# 1040                           5
# 1041                           5
# 1042                           5
# 585                            4
# 1188                           4
# 1190                           4
# 1584                           4
# 1191                           4
#
#                            coisolated_precursor_mz_list assumed_adduct  \
# 1043  [343.0795742879019, 343.1034858493162, 343.140...         [M-H]-
# 1112  [301.0318475693559, 301.05811512533637, 301.10...         [M-H]-
# 1040  [343.0795742879019, 343.1034858493162, 343.140...         [M-H]-
# 1041  [343.0795742879019, 343.1034858493162, 343.140...         [M-H]-
# 1042  [343.0795742879019, 343.1034858493162, 343.140...         [M-H]-
# 585   [225.00378470652512, 225.03707331127316, 225.0...         [M-H]-
# 1188  [341.08770186237416, 341.13064540632854, 341.1...         [M-H]-
# 1190  [341.08770186237416, 341.13064540632854, 341.1...         [M-H]-
# 1584  [327.0723861988474, 327.112456780347, 327.1805...         [M-H]-
# 1191  [341.08770186237416, 341.13064540632854, 341.1...         [M-H]-
#
#      predicted_formula  estimated_fdr  \
# 1043        C19H28N4O2   0.000000e+00
# 1112          C14H22O7   0.000000e+00
# 1040          C15H20O9   5.082965e-09
# 1041          C16H24O8   1.488036e-02
# 1042          C17H28O7   0.000000e+00
# 585           C12H18O4   1.130873e-07
# 1188          C15H18O9   6.828871e-05
# 1190          C17H26O7   0.000000e+00
# 1584          C18H32O5   0.000000e+00
# 1191          C18H30O6   5.951043e-09
#
#                           deconvoluted_spectrum_mz_vals  \
# 1043        [299.18884, 299.2265, 307.19165, 325.20358]
# 1112       [185.15382, 195.13893, 213.14984, 229.14413]
# 1040  [165.12871, 195.10341, 209.11829, 211.13391, 2...
# 1041       [195.13953, 223.13383, 237.15013, 255.16031]
# 1042       [267.16125, 275.15033, 281.17548, 325.16373]
# 585                     [157.0868, 181.12378, 197.0795]
# 1188                     [149.0973, 163.1126, 209.1182]
# 1190  [235.16718, 253.17906, 265.14468, 279.16022, 2...
# 1584  [265.21875, 283.1937, 283.2287, 291.1964, 309....
# 1191         [279.19742, 297.2084, 305.1759, 323.18665]
#
#                    deconvoluted_spectrum_intensity_vals  \
# 1043        [3514.345, 2299.0498, 10157.727, 28929.775]
# 1112         [10119.421, 7883.9907, 2633.1753, 7638.97]
# 1040  [2199.623, 5480.181, 16091.89, 22295.535, 2161...
# 1041          [1987.2334, 2669.3396, 3798.885, 5211.44]
# 1042         [4917.2964, 4561.711, 2448.8008, 2785.807]
# 585                   [23874.125, 1779.4579, 3364.2898]
# 1188                  [4079.4778, 2186.7847, 24066.441]
# 1190  [1547.353, 2397.539, 2809.9324, 3273.9338, 331...
# 1584  [8281.501, 5626.5293, 9580.316, 57769.18, 9882...
# 1191       [4285.2266, 5504.6797, 28437.957, 40226.184]
#
#                               original_spectrum_mz_vals  \
# 1043  [215.12862, 223.09627, 223.13383, 225.15053, 2...
# 1112  [221.15338, 223.13022, 226.028, 227.03514, 237...
# 1040  [215.12862, 223.09627, 223.13383, 225.15053, 2...
# 1041  [215.12862, 223.09627, 223.13383, 225.15053, 2...
# 1042  [215.12862, 223.09627, 223.13383, 225.15053, 2...
# 585   [167.03519, 165.01912, 157.0868, 153.08978, 13...
# 1188  [223.13388, 243.17622, 235.16718, 235.13438, 2...
# 1190  [223.13388, 243.17622, 235.16718, 235.13438, 2...
# 1584  [247.20634, 243.1603, 239.20078, 231.462, 227....
# 1191  [223.13388, 243.17622, 235.16718, 235.13438, 2...
#
#                        original_spectrum_intensity_vals
# 1043  [2426.6694, 2161.1072, 2669.3396, 2391.8945, 1...
# 1112  [1866.7537, 2054.268, 3815.6853, 6462.6787, 17...
# 1040  [2426.6694, 2161.1072, 2669.3396, 2391.8945, 1...
# 1041  [2426.6694, 2161.1072, 2669.3396, 2391.8945, 1...
# 1042  [2426.6694, 2161.1072, 2669.3396, 2391.8945, 1...
# 585   [1904.4008, 7457.445, 23874.125, 9689.003, 196...
# 1188  [3384.5376, 2436.0469, 1547.353, 3462.9326, 10...
# 1190  [3384.5376, 2436.0469, 1547.353, 3462.9326, 10...
# 1584  [31215.697, 3395.8184, 3732.539, 2811.4077, 17...
# 1191  [3384.5376, 2436.0469, 1547.353, 3462.9326, 10...
