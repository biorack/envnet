# %%
### Preprocessing requirements
import pandas as pd
# 1. Copy all .h5 and .mzML files from the job folders to a single output directory for easier access.
# 2. Run the deconvolution to make <filename>_deconvoluted.parquet files.
import os
import numpy as np
from scipy.stats import ttest_ind
# import ztest
from statsmodels.stats.weightstats import ztest
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches

PYTHONPATH = "/global/homes/b/bpb/repos/envnet"
if PYTHONPATH not in sys.path:
    sys.path.insert(0, PYTHONPATH)

from envnet.annotation.core import AnnotationEngine
annotation_engine = AnnotationEngine()
ref_dir = '/global/homes/b/bpb/repos/envnet/results/full_build_20250908_181404/'
node_data = annotation_engine.load_envnet_reference(
    graphml_file=os.path.join(ref_dir, "network_with_sirius.graphml"),
    mgf_base_name=os.path.join(ref_dir, "envnet")
)   
cols = [ 'dbe', 'dbe_ai',
       'dbe_ai_mod', 'ai_mod', 'ai', 'nosc', 'h_to_c', 'o_to_c', 'n_to_c',
       'p_to_c', 'c', 'h', 'o', 'n', 's', 'p', 'original_index','precursor_mz','inchi_key', 'compound_name', 'smiles','NPC#pathway', 'NPC#superclass', 'NPC#class','predicted_formula']

cols = ['original_index','predicted_unchanged_in_soil_prob', 'predicted_unchanged_in_soil']
model_data = pd.read_csv('../envnet/data/node_data_with_predicted_unchanged_20251107.csv', usecols=cols)
node_data['nodes'] = node_data['nodes'].merge(model_data, on='original_index', how='left')
# Out:
# Loading ENVnet reference data...
#   GraphML file: /global/homes/b/bpb/repos/envnet/results/full_build_20250908_181404/network_with_sirius.graphml
#   Deconvoluted MGF: /global/u2/b/bpb/repos/envnet/data//global/homes/b/bpb/repos/envnet/results/full_build_20250908_181404/envnet_deconvoluted_spectra.mgf
#   Original MGF: /global/u2/b/bpb/repos/envnet/data//global/homes/b/bpb/repos/envnet/results/full_build_20250908_181404/envnet_original_spectra.mgf
# Loaded 22128 ENVnet nodes

# %%
pmz = node_data['reference_pmzs']
spectra = node_data['deconvoluted_spectra']

# %%
import pandas as pd
import argparse
import os
import json
import requests
import time
from tqdm import tqdm

# this is sychronous low performance
def query_fasst_usi(usi, database, host="https://fasst.gnps2.org",
                    analog=False, precursor_mz_tol=0.05,
                    fragment_mz_tol=0.05, min_cos=0.7,
                    cache="Yes"):
    params = {
        "usi": usi,
        "library": database,
        "analog": "Yes" if analog else "No",
        "pm_tolerance": precursor_mz_tol,
        "fragment_tolerance": fragment_mz_tol,
        "cosine_threshold": min_cos,
        "cache": cache
    }

    r = requests.get(os.path.join(host, "search"), params=params, timeout=50)
    r.raise_for_status()

    return r.json()

# high performance version
def query_fasst_api_usi(usi, database, host="https://api.fasst.gnps2.org",
                    analog=False, precursor_mz_tol=0.05,
                    fragment_mz_tol=0.05, min_cos=0.7,
                    cache="Yes",
                    lower_delta=100,
                    upper_delta=100,
                    blocking=True):
    
    params = {
        "library": database,
        "usi": usi,
        "analog": "Yes" if analog else "No",
        "cache": "No",
        "lower_delta": lower_delta,
        "upper_delta": upper_delta,
        "pm_tolerance": precursor_mz_tol,
        "fragment_tolerance": fragment_mz_tol,
        "cosine_threshold": min_cos
    }


    r = requests.post(os.path.join(host, "search"), json=params, timeout=5)
    r.raise_for_status()

    task_id = r.json()["id"]
    
    params["task_id"] = task_id
    params["status"] = "PENDING"

    if blocking is False:
        return params

    return get_results(params, host=host)

def query_fasst_peaks(precursor_mz, peaks, database, host="https://fasst.gnps2.org", analog=False, precursor_mz_tol=0.05, fragment_mz_tol=0.05, min_cos=0.7):
    spectrum_query = {
        "peaks": peaks,
        "precursor_mz": precursor_mz
    }

    params = {
        "query_spectrum": json.dumps(spectrum_query),
        "library": database,
        "analog": "Yes" if analog else "No",
        "pm_tolerance": precursor_mz_tol,
        "fragment_tolerance": fragment_mz_tol,
        "cosine_threshold": min_cos,
    }

    r = requests.post(os.path.join(host, "search"), data=params, timeout=50)

    r.raise_for_status()

    return r.json()



def query_fasst_api_peaks(precursor_mz, peaks, database, 
                          host="https://api.fasst.gnps2.org", 
                          analog=False, precursor_mz_tol=0.05, 
                          fragment_mz_tol=0.05, 
                          min_cos=0.7, 
                          lower_delta=100,
                          upper_delta=100,
                          blocking=True):
    spectrum_query = {
        "peaks": peaks,
        "precursor_mz": precursor_mz
    }

    params = {
        "library": database,
        "query_spectrum": json.dumps(spectrum_query),
        "analog": "Yes" if analog else "No",
        "cache": "No",
        "lower_delta": lower_delta,
        "upper_delta": upper_delta,
        "pm_tolerance": precursor_mz_tol,
        "fragment_tolerance": fragment_mz_tol,
        "cosine_threshold": min_cos
    }

    query_url = os.path.join(host, "search")

    r = requests.post(query_url, json=params, timeout=5)
    
    r.raise_for_status()

    task_id = r.json()["id"]

    params["task_id"] = task_id
    params["status"] = "PENDING"
    
    if blocking is False:
        return params

    return params


def get_results(query_parameters_dictionary, host="https://api.fasst.gnps2.org", blocking=True):
    task_id = query_parameters_dictionary["task_id"]
    
    retries_max = 120
    current_retries = 0
    while True:
        print("WAITING FOR RESULTS", current_retries, task_id)
        
        r = requests.get(os.path.join(host, "search/result/{}".format(task_id)), timeout=30)

        try:
            r.raise_for_status()
        except KeyboardInterrupt:
            raise
        except:
            # if we are not blocking, we just return the status
            if blocking is False:
                return "PENDING"
            
            time.sleep(1)
            current_retries += 1
            

            continue


        # checking if the results are ready
        if "status" in r.json() and r.json()["status"] == "PENDING":
            # if we are not blocking, we just return the status
            if blocking is False:
                return "PENDING"
            
            time.sleep(1)
            current_retries += 1

            if current_retries >= retries_max:
                raise Exception("Timeout waiting for results from FASST API")
            
            continue

        results_dict = r.json()
    
        return results_dict

def get_databases(host="https://fasst.gnps2.org"):
    url = "{}/libraries".format(host)

    return requests.get(url).json()

# %%
peaks = spectra[0].T.tolist()
# Out:
# [[199.20680236816406, 2683.6484375],
#  [207.17523193359375, 11063.068359375],
#  [225.18592834472656, 43173.1484375],
#  [241.18096923828125, 9991.2373046875]]

# %%
database_label = 'metabolomicspanrepo_index_nightly'
usi = "mzspec:GNPS:GNPS-LIBRARY:accession:CCMSLIB00005883671"
query_fasst_usi(usi, database_label, host="https://fasst.gnps2.org",
                    analog=False, precursor_mz_tol=0.05,
                    fragment_mz_tol=0.05, min_cos=0.7,
                    cache="Yes")
# Out:
# {'results': [{'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000095708:peak/mzML/WB23L029.mzML:scan:969',
#    'Charge': 1,
#    'Cosine': 0.73,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000095708',
#    'Status': 'NoID',
#    'Query Filename': 'temp/queries/5d/5db576874736475eb3119e7e34246616/5db576874736475eb3119e7e34246616.mgf',
#    'Query Scan': 1,
#    'Index UnitPM': 104,
#    'Index IdxInUnitPM': 985404,
#    'Filtered Input Spectrum Path': 'temp/queries/5d/5db576874736475eb3119e7e34246616/0.json'},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000095708:peak/mzML/TL23L007.mzML:scan:1056',
#    'Charge': 1,
#    'Cosine': 0.73,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000095708',
#    'Status': 'NoID',
#    'Query Filename': 'temp/queries/5d/5db576874736475eb3119e7e34246616/5db576874736475eb3119e7e34246616.mgf',
#    'Query Scan': 1,
#    'Index UnitPM': 104,
#    'Index IdxInUnitPM': 987637,
#    'Filtered Input Spectrum Path': 'temp/queries/5d/5db576874736475eb3119e7e34246616/0.json'},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000082616:peak/Pos_LI_mzXML/GIMap_P1_LI_Aq-Org_Mixed_B5.mzXML:scan:3183',
#    'Charge': 1,
#    'Cosine': 0.73,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000082616',
#    'Status': 'NoID',
#    'Query Filename': 'temp/queries/5d/5db576874736475eb3119e7e34246616/5db576874736475eb3119e7e34246616.mgf',
#    'Query Scan': 1,
#    'Index UnitPM': 104,
#    'Index IdxInUnitPM': 1006670,
#    'Filtered Input Spectrum Path': 'temp/queries/5d/5db576874736475eb3119e7e34246616/0.json'},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:ST003818:rawdata/P_QC3.mzML:scan:2465',
#    'Charge': 1,
#    'Cosine': 0.73,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'ST003818',
#    'Status': 'NoID',
#    'Query Filename': 'temp/queries/5d/5db576874736475eb3119e7e34246616/5db576874736475eb3119e7e34246616.mgf',
#    'Query Scan': 1,
#    'Index UnitPM': 104,
#    'Index IdxInUnitPM': 1607901,
#    'Filtered Input Spectrum Path': 'temp/queries/5d/5db576874736475eb3119e7e34246616/0.json'},
#   {'Delta Mass': 0.0,
#    'USI': 'mzspec:MSV000095423:peak/all_files_mzML/LC1_1to100/HNRC_P3_D9_Sample_X3157299_100H2O_LC1.mzML:scan:5622',
#    'Charge': 1,
#    'Cosine': 0.72,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000095423',
#    'Status': 'NoID',
#    'Query Filename': 'temp/queries/5d/5db576874736475eb3119e7e34246616/5db576874736475eb3119e7e34246616.mgf',
#    'Query Scan': 1,
#    'Index UnitPM': 104,
#    'Index IdxInUnitPM': 1294659,
#    'Filtered Input Spectrum Path': 'temp/queries/5d/5db576874736475eb3119e7e34246616/0.json'},
#   {'Delta Mass': 0.0,
#    'USI': 'mzspec:ST002956:X0141-M002A-107_2C3.mzML:scan:28',
#    'Charge': 1,
#    'Cosine': 0.72,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'ST002956',
#    'Status': 'NoID',
#    'Query Filename': 'temp/queries/5d/5db576874736475eb3119e7e34246616/5db576874736475eb3119e7e34246616.mgf',
#    'Query Scan': 1,
#    'Index UnitPM': 104,
#    'Index IdxInUnitPM': 1605052,
#    'Filtered Input Spectrum Path': 'temp/queries/5d/5db576874736475eb3119e7e34246616/0.json'},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000091033:raw/20210831_KAO_HILIC_T1102M_20210413_10wk_RBG.mzML:scan:784',
#    'Charge': 1,
#    'Cosine': 0.72,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000091033',
#    'Status': 'NoID',
#    'Query Filename': 'temp/queries/5d/5db576874736475eb3119e7e34246616/5db576874736475eb3119e7e34246616.mgf',
#    'Query Scan': 1,
#    'Index UnitPM': 104,
#    'Index IdxInUnitPM': 1368073,
#    'Filtered Input Spectrum Path': 'temp/queries/5d/5db576874736475eb3119e7e34246616/0.json'},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000097132:raw/mapp_batch_00020/20220607_PMA_MAPP_01_22_011.mzML:scan:1061',
#    'Charge': 1,
#    'Cosine': 0.71,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000097132',
#    'Status': 'NoID',
#    'Query Filename': 'temp/queries/5d/5db576874736475eb3119e7e34246616/5db576874736475eb3119e7e34246616.mgf',
#    'Query Scan': 1,
#    'Index UnitPM': 104,
#    'Index IdxInUnitPM': 1032104,
#    'Filtered Input Spectrum Path': 'temp/queries/5d/5db576874736475eb3119e7e34246616/0.json'},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000095784:peak/mzML/MCR23LVR6.mzML:scan:995',
#    'Charge': 1,
#    'Cosine': 0.71,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000095784',
#    'Status': 'NoID',
#    'Query Filename': 'temp/queries/5d/5db576874736475eb3119e7e34246616/5db576874736475eb3119e7e34246616.mgf',
#    'Query Scan': 1,
#    'Index UnitPM': 104,
#    'Index IdxInUnitPM': 545415,
#    'Filtered Input Spectrum Path': 'temp/queries/5d/5db576874736475eb3119e7e34246616/0.json'},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000097132:ccms_peak/mapp_batch_00020/20220607_PMA_MAPP_01_22_011.mzML:scan:1061',
#    'Charge': 1,
#    'Cosine': 0.71,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000097132',
#    'Status': 'NoID',
#    'Query Filename': 'temp/queries/5d/5db576874736475eb3119e7e34246616/5db576874736475eb3119e7e34246616.mgf',
#    'Query Scan': 1,
#    'Index UnitPM': 104,
#    'Index IdxInUnitPM': 1032333,
#    'Filtered Input Spectrum Path': 'temp/queries/5d/5db576874736475eb3119e7e34246616/0.json'}],
#  'timing': [{'desc': 'prep', 'timing': 0.0020198822021484375},
#   {'desc': 'Search', 'timing': 1.0551197528839111},
#   {'desc': 'Parse Query', 'timing': 0.00016689300537109375},
#   {'desc': 'Parse Query 2', 'timing': 0.00433802604675293},
#   {'desc': 'Get DB Info', 'timing': 0.0001246929168701172},
#   {'desc': 'Demangle', 'timing': 0.012201786041259766},
#   {'desc': 'Group', 'timing': 0.01590418815612793},
#   {'desc': 'Enrich datasets', 'timing': 0.026119470596313477}],
#  'grouped_by_unit_delta_mass': [{'Frequency': 10, 'Unit Delta Mass': 0},
#   {'Frequency': 1, 'Unit Delta Mass': -1},
#   {'Frequency': 1, 'Unit Delta Mass': 1}],
#  'grouped_by_dataset': [{'Frequency': 2, 'Dataset': 'MSV000097132'},
#   {'Frequency': 2, 'Dataset': 'MSV000095708'},
#   {'Frequency': 1, 'Dataset': 'MSV000082869'},
#   {'Frequency': 1, 'Dataset': 'MSV000082616'},
#   {'Frequency': 1, 'Dataset': 'MSV000095423'},
#   {'Frequency': 1, 'Dataset': 'MSV000091033'},
#   {'Frequency': 1, 'Dataset': 'MSV000095784'},
#   {'Frequency': 1, 'Dataset': 'ST002956'},
#   {'Frequency': 1, 'Dataset': 'ST003223'},
#   {'Frequency': 1, 'Dataset': 'ST003818'}],
#  'grouped_by_dataset_unit_delta': [{'Frequency': 2,
#    'Dataset': 'MSV000097132',
#    'Unit Delta Mass': 0},
#   {'Frequency': 2, 'Dataset': 'MSV000095708', 'Unit Delta Mass': 0},
#   {'Frequency': 1, 'Dataset': 'MSV000082869', 'Unit Delta Mass': -1},
#   {'Frequency': 1, 'Dataset': 'MSV000082616', 'Unit Delta Mass': 0},
#   {'Frequency': 1, 'Dataset': 'MSV000095423', 'Unit Delta Mass': 0},
#   {'Frequency': 1, 'Dataset': 'MSV000091033', 'Unit Delta Mass': 0},
#   {'Frequency': 1, 'Dataset': 'MSV000095784', 'Unit Delta Mass': 0},
#   {'Frequency': 1, 'Dataset': 'ST002956', 'Unit Delta Mass': 0},
#   {'Frequency': 1, 'Dataset': 'ST003223', 'Unit Delta Mass': 1},
#   {'Frequency': 1, 'Dataset': 'ST003818', 'Unit Delta Mass': 0}],
#  'metadata_groupings': [],
#  'log': 'bin/main_execmodule ExecIndex bin/generic_params -autoINPUT_INDEX libraries/metabolomicspanrepo_index_nightly/build_index -autoOUTPUT_RESULTS temp/queries/5d/5db576874736475eb3119e7e34246616/5db576874736475eb3119e7e34246616.tsv -autoINPUT_SPECS temp/queries/5d/5db576874736475eb3119e7e34246616/5db576874736475eb3119e7e34246616.mgf -autoPM_TOLERANCE 0.05 -autoFRAG_TOLERANCE 0.05 -autoDELTA_MZ_ABOVE 0 -autoDELTA_MZ_BELOW 0 -autoTHETA 0.7 -autoSPECTRUM_DISK_ACCESS_POLICY DISK -autoINDEX_DISK_ACCESS_POLICY DISK -autoOUTPUT_FILTERED_QUERIES_JSON_FOLDER temp/queries/5d/5db576874736475eb3119e7e34246616 -autoDELTA_F 0.4 -autoVALIDATE 0\n---\nDEBUG: /_sps/src/ExecFramework/main_execmodule.cpp : 151\nDEBUG: /_sps/src/ExecFramework/ExecSpecTagGen.cpp : 20\nDEBUG: /_sps/src/ExecFramework/ExecSpecTagGen.cpp : 20\nDEBUG: /_sps/src/ExecFramework/ExecPenaltyGen.cpp : 26\nDEBUG: /_sps/src/ExecFramework/ExecPenaltyGen.cpp : 26\nDEBUG: /_sps/src/ExecFramework/main_execmodule.cpp : 155\nDEBUG: /_sps/src/ExecFramework/main_execmodule.cpp : 166\nDEBUG: /_sps/src/ExecFramework/main_execmodule.cpp : 176: jobDoneFile = ExecIndex__results.param\nDEBUG: /_sps/src/ExecFramework/main_execmodule.cpp : 225: NORMAL EXECUTION\nDEBUG: /_sps/src/ExecFramework/main_execmodule.cpp : 226\nDEBUG: /_sps/src/proj/indexing/Index.h : 520: Index version not compatible with this binary\nDEBUG: /_sps/src/proj/indexing/Index.h : 522: Loaded processing parameters\nDEBUG: /_sps/src/proj/indexing/Index.h : 368: Size: 8342800\nDEBUG: /_sps/src/proj/indexing/Index.h : 485: Loaded filenames\nDEBUG: /_sps/src/proj/indexing/Index.h : 512: Not loading annotations in advance, will do so per-spectrum\nDEBUG: /_sps/src/ExecFramework/proj/indexing/ExecIndex.cpp : 899: Loaded 10000 bins!\nDEBUG: /_sps/src/ExecFramework/proj/indexing/ExecIndex.cpp : 1031: 100\nDEBUG: /_sps/src/ExecFramework/proj/indexing/ExecIndex.cpp : 1040: temp/queries/5d/5db576874736475eb3119e7e34246616/5db576874736475eb3119e7e34246616.mgf: 1\nDEBUG: /_sps/src/ExecFramework/proj/indexing/ExecIndex.cpp : 1055: Loaded 1 input spectra.\nDEBUG: /_sps/src/ExecFramework/main_execmodule.cpp : 235\nDEBUG: /_sps/src/ExecFramework/main_execmodule.cpp : 238: Began Invoke of: [ExecIndex] at: Thu Dec 11 18:53:32 2025\n\nDEBUG: /_sps/src/ExecFramework/proj/indexing/ExecIndex.cpp : 83: Start\nDEBUG: /_sps/src/ExecFramework/proj/indexing/ExecIndex.cpp : 733: m_params.getValueBool("REFERENCE_RUN", false) = 0\nDEBUG: /_sps/src/ExecFramework/proj/indexing/ExecIndex.cpp : 763: Running with 0.05 Da parent mass tolerance (1 index units)\nDEBUG: /_sps/src/ExecFramework/proj/indexing/ExecIndex.cpp : 764: Running with 0.05 Da fragment mass tolerance (1 index units)\nDEBUG: /_sps/src/ExecFramework/proj/indexing/ExecIndex.cpp : 793: Writing out filtered queries\nDEBUG: /_sps/src/proj/indexing/QueryRunner.h : 38: PM Range for Query Runner:0 - 10000\nDEBUG: /_sps/src/proj/indexing/QueryRunner.h : 167: Loaded: 103\nDEBUG: /_sps/src/proj/indexing/Index.h : 312: Inputting  "libraries/metabolomicspanrepo_index_nightly/build_index/103.mxc"\nDEBUG: /_sps/src/proj/indexing/QueryRunner.h : 218: temp/queries/5d/5db576874736475eb3119e7e34246616/5db576874736475eb3119e7e34246616.mgf:1 @ 104.05\nDEBUG: /_sps/src/proj/indexing/QueryRunner.h : 291: Ran in 619/287 us and 6 is the size of q (20072 us to determine candidates/1842 us for cosine) and generated 229 true final_candidate_count (0 tp)/0 candidates in 15464/29812 list accesses out of 0 total spectra in search space searched in 0 us.\nDEBUG: /_sps/src/proj/indexing/QueryRunner.h : 312: Total reads: 527\nDEBUG: /_sps/src/proj/indexing/QueryRunner.h : 313: Total bytes read: 764764\nDEBUG: /_sps/src/proj/indexing/QueryRunner.h : 314: Histogram 0 1 229 85 144 0 0 1 11 22 16 3 0 1 14 0\nDEBUG: /_sps/src/proj/indexing/QueryRunner.h : 145: Reset: 103\nDEBUG: /_sps/src/proj/indexing/QueryRunner.h : 167: Loaded: 104\nDEBUG: /_sps/src/proj/indexing/Index.h : 312: Inputting  "libraries/metabolomicspanrepo_in ...

# %%
# Get the file list for various MASST databases here
# https://github.com/robinschmid/microbe_masst/tree/master/data

# %%
database_label = 'metabolomicspanrepo_index_nightly'
outdir = '/pscratch/sd/b/bpb/envnet_masst_results'
for i in range(len(pmz)):
    outfile = os.path.join(outdir, f'fasst_query_result_%d.json'%i)
    if os.path.exists(outfile):
        continue
    peaks = spectra[i].T.tolist()
    precursor_mz = pmz[i]
    
    params = query_fasst_api_peaks(precursor_mz, peaks, database_label, 
                            host="https://api.fasst.gnps2.org", 
                            analog=False, precursor_mz_tol=0.05, 
                            fragment_mz_tol=0.05, 
                            min_cos=0.7, 
                            lower_delta=100,
                            upper_delta=100,
                            blocking=True)

    results = get_results(params, host="https://api.fasst.gnps2.org", blocking=True)
    results['envnet_index'] = i
    with open(outfile, 'w') as f:
        json.dump(results, f)

# %%
results
# Out:
# {'results': [{'Delta Mass': -0.04,
#    'USI': 'mzspec:MTBLS10526:FILES/DERIVED_FILES/FA12a_72.mzML:scan:30396',
#    'Charge': 1,
#    'Cosine': 1.0,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MTBLS10526',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 7522489},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000089289:peak/209_MT_CCE21.mzML:scan:448',
#    'Charge': 1,
#    'Cosine': 0.97,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000089289',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 3248736},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000089289:ccms_peak/209_MT_CCE21.mzML:scan:448',
#    'Charge': 1,
#    'Cosine': 0.97,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000089289',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 3247116},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000084738:ccms_peak/Delicatisima_MT_120319_1.mzML:scan:451',
#    'Charge': 1,
#    'Cosine': 0.97,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000084738',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 3304569},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000094118:peak/mzML/20210525_Preblank1.mzML:scan:909',
#    'Charge': 1,
#    'Cosine': 0.96,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000094118',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4930151},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000094118:peak/mzML/20210525_Preblank1.mzML:scan:105',
#    'Charge': 1,
#    'Cosine': 0.96,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000094118',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4930139},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_235.mzML:scan:857',
#    'Charge': 1,
#    'Cosine': 0.95,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4793749},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000094118:peak/mzML/20210525_SPE1.mzML:scan:1500',
#    'Charge': 1,
#    'Cosine': 0.95,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000094118',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4930273},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000081731:ccms_peak/170829_Irina_Pseudo_nitzschia_posMSMS/Pn_subpacifica_A_DOM_I.mzML:scan:444',
#    'Charge': 1,
#    'Cosine': 0.95,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000081731',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 2585119},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000081731:ccms_peak/170829_Irina_Pseudo_nitzschia_posMSMS/Pn_subpacifica_A_Unfil_II.mzML:scan:452',
#    'Charge': 1,
#    'Cosine': 0.95,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000081731',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 2584973},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000095803:peak/mzML/LB2.mzML:scan:1461',
#    'Charge': 1,
#    'Cosine': 0.95,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000095803',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 5858737},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000079819:ccms_peak/160610_homogenized_control/Wine.mzXML:scan:3373',
#    'Charge': 1,
#    'Cosine': 0.95,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000079819',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 3160185},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000079819:ccms_peak/160610_homogenized_control/Human_molar_160610190608.mzXML:scan:2610',
#    'Charge': 1,
#    'Cosine': 0.95,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000079819',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 3160223},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000080562:peak/170220_DOM_V-opti_MS1_MSMS/mzxml/Blank_4_MSMS.mzXML:scan:514',
#    'Charge': 1,
#    'Cosine': 0.95,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000080562',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 3003304},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MTBLS10526:FILES/DERIVED_FILES/BH24_72.mzML:scan:30655',
#    'Charge': 1,
#    'Cosine': 0.95,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MTBLS10526',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 7522470},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000081731:ccms_peak/170829_Irina_Pseudo_nitzschia_posMSMS/Pn_subpacifica_A_DOM_II.mzML:scan:462',
#    'Charge': 1,
#    'Cosine': 0.95,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000081731',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 2585110},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000083631:peak/PEAKS/O1903316.mzXML:scan:238',
#    'Charge': 1,
#    'Cosine': 0.95,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000083631',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 2469339},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_229.mzML:scan:848',
#    'Charge': 1,
#    'Cosine': 0.95,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4785577},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_231.mzML:scan:850',
#    'Charge': 1,
#    'Cosine': 0.95,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4794172},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/MO23S_051_Blank_r.mzML:scan:436',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4806179},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000081731:ccms_peak/170829_Irina_Pseudo_nitzschia_posMSMS/Pn_subpacifica_B_DOM_I.mzML:scan:370',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000081731',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 2584786},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000087944:peak/Peak_List_Files/PNACIC_SARS2plasmid_ORF3a_B08_R5__Pos_09Jun20_Brandi-WCSH115315.mzML:scan:691',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000087944',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 1287091},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000083631:peak/PEAKS/O1903329.mzXML:scan:136',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000083631',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 2469890},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000080562:peak/170220_DOM_V-opti_MS1_MSMS/mzxml/100_D_MSMS.mzXML:scan:577',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000080562',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 3003205},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:ST001861:20190525_Indranil_pos_spme_meta10_2.mzML:scan:11158',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'ST001861',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 6900216},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_083.mzML:scan:312',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4792616},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MTBLS10526:FILES/DERIVED_FILES/B3S.mzML:scan:30904',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MTBLS10526',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 7522590},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000079568:ccms_peak/137ST_100pM.mzXML:scan:3591',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000079568',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 1808519},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_233.mzML:scan:881',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4794570},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000080562:peak/170220_DOM_V-opti_MS1_MSMS/mzxml/Blank_5_MSMS.mzXML:scan:722',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000080562',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 3003257},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MTBLS10526:FILES/DERIVED_FILES/FA9.mzML:scan:30254',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MTBLS10526',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 7522639},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MTBLS10526:FILES/DERIVED_FILES/BH27b_72.mzML:scan:30041',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MTBLS10526',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 7522445},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MTBLS10526:FILES/DERIVED_FILES/FA10_72.mzML:scan:30598',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MTBLS10526',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 7522354},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MTBLS10526:FILES/DERIVED_FILES/FAB3b.mzML:scan:29272',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MTBLS10526',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 7522427},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Blank_38.mzML:scan:438',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4807659},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MTBLS12372:FILES/DERIVED_FILES/20240528_Proj25-24_NZF_45-45_R84P.mzML:scan:4294967295',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MTBLS12372',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 7297128},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MTBLS10526:FILES/DERIVED_FILES/BH19.mzML:scan:30742',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MTBLS10526',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 7522516},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MTBLS10526:FILES/DERIVED_FILES/BH27b_72.mzML:scan:30240',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MTBLS10526',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 7522446},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000083631:peak/PEAKS/O1903319.mzXML:scan:208',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000083631',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 2469347},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000080562:peak/170220_DOM_V-opti_MS1_MSMS/mzxml/Blank_3_MSMS.mzXML:scan:304',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000080562',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 3003092},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000098454:peak/liangtro/MS2_7.mzML:scan:2031',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000098454',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 1214071},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000098454:ccms_peak/liangtro/MS2_7.mzML:scan:2031',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000098454',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 1213982},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_101.mzML:scan:417',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4792652},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000087944:ccms_peak/Raw_Spectrum_Files/PNACIC_SARS2plasmid_ORF3a_B08_R5__Pos_09Jun20_Brandi-WCSH115315.mzML:scan:691',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000087944',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 1288565},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000080562:peak/170220_DOM_V-opti_MS1_MSMS/mzxml/Blank_5_MSMS.mzXML:scan:489',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000080562',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 3003249},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_075.mzML:scan:414',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4783648},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000085843:ccms_peak/raw/XA_DOM_50.mzML:scan:1216',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000085843',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 5599484},
#   {'Delta Mass': 0.0,
#    'USI': 'mzspec:MSV000082083:ccms_peak/MORDOR_raw/raw/Mo_2017_DOM_129.mzML:scan:194',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000082083',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 405425},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000081731:ccms_peak/170829_Irina_Pseudo_nitzschia_posMSMS/Pn_multiseries_B_DOM_II.mzML:scan:395',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000081731',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 2585269},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_226.mzML:scan:1049',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4809194},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_201.mzML:scan:855',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4799413},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MTBLS10526:FILES/DERIVED_FILES/F3S.mzML:scan:29927',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MTBLS10526',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 7522603},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_109.mzML:scan:399',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4786871},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_073.mzML:scan:349',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4808053},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/MO23S_088r.mzML:scan:341',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4789266},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/MO23S_048r.mzML:scan:426',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4792072},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MTBLS10526:FILES/DERIVED_FILES/FA3.mzML:scan:30652',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MTBLS10526',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 7522334},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000083631:peak/PEAKS/O1903311.mzXML:scan:226',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000083631',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 2469540},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000083631:peak/PEAKS/O1903352.mzXML:scan:208',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000083631',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 2469683},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000083631:peak/PEAKS/O1903327.mzXML:scan:96',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000083631',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 2469857},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000083631:peak/PEAKS/O1903329.mzXML:scan:109',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000083631',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 2469889},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000080533:ccms_peak/nist_STDS_POS_MZXML/NIST_STD_001_b.mzXML:scan:13085',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000080533',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 3495475},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MTBLS10526:FILES/DERIVED_FILES/BH19.mzML:scan:30451',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MTBLS10526',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 7522514},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MTBLS10526:FILES/DERIVED_FILES/BH24_72.mzML:scan:30556',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MTBLS10526',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 7522469},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000083631:peak/PEAKS/O1903343.mzXML:scan:232',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000083631',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 2469886},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MTBLS10526:FILES/DERIVED_FILES/BH19.mzML:scan:30544',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MTBLS10526',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 7522515},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_083.mzML:scan:418',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4792619},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Blank34.mzML:scan:446',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4802876},
#   {'Delta Mass': 0.0,
#    'USI': 'mzspec:MSV000090123:peak/mzml/samples/P2107_174.mzML:scan:365',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000090123',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 631086},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MTBLS10526:FILES/DERIVED_FILES/F3S.mzML:scan:30028',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MTBLS10526',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 7522604},
#   {'Delta Mass': 0.0,
#    'USI': 'mzspec:MSV000090123:ccms_peak/raw/P2107_174.mzML:scan:365',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000090123',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 632167},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/MO23S_094_Blank_r.mzML:scan:435',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4804620},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_094.mzML:scan:407',
#    'Charge': 1,
#    'Cosine': 0.94,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4786715},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000098454:ccms_peak/liangtro/MS2_7.mzML:scan:2955',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000098454',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 1213997},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/MO23S_095.mzML:scan:376',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4789376},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000090798:ccms_peak/raw_pos/Mutant_raw_pos/std2_7_21.mzML:scan:778',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000090798',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 481001},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_089.mzML:scan:368',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4786477},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Blank8.mzML:scan:404',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4804081},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/MO23S_007.mzML:scan:376',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4808088},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/MO23S_109r.mzML:scan:421',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4781420},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_064.mzML:scan:324',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4790933},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000080562:peak/170220_DOM_V-opti_MS1_MSMS/mzxml/Blank_4_MSMS.mzXML:scan:272',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000080562',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 3003296},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_091.mzML:scan:403',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4782969},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000088021:peak/mzML/Moorea19_PlanC/Mo_2019_114.mzML:scan:492',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000088021',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 5960009},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:ST001861:20190525_Indranil_pos_spme_meta1_2.mzML:scan:10004',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'ST001861',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 6901946},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_089.mzML:scan:397',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4786478},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_221r.mzML:scan:454',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4806766},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000080562:peak/170220_DOM_V-opti_MS1_MSMS/mzxml/Blank_5_MSMS.mzXML:scan:1051',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000080562',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 3003268},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Blank8.mzML:scan:337',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4804079},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000098454:peak/liangtro/MS2_19.mzML:scan:2558',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000098454',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 1214549},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000098454:ccms_peak/liangtro/MS2_19.mzML:scan:2558',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000098454',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 1218375},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_058.mzML:scan:399',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4782999},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_213.mzML:scan:1056',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4782152},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000089289:peak/268_MT_CCE21.mzML:scan:345',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000089289',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 3246292},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_228r.mzML:scan:458',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4785909},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_228r.mzML:scan:428',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4785908},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/MO23S_064r.mzML:scan:4197',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4794972},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_078.mzML:scan:423',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4785610},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000086759:peak/sarahi_QE_01242021/MC81.mzXML:scan:498',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000086759',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 2385099},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000088021:ccms_peak/210619_Moorea19_PlanC/Mo_2019_114.mzML:scan:492',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000088021',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 5975443},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000089289:ccms_peak/268_MT_CCE21.mzML:scan:345',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000089289',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 3247814},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000088021:updates/2021-10-11_ikoester_a6273ef2/peak/mzMLcorr/21019_PlanC/Mo_2019_114.mzML:scan:492',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000088021',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 5968815},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/MO23S_005.mzML:scan:355',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4783930},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000079651:ccms_peak/100pM.mzXML:scan:2507',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000079651',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 3853476},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000094118:peak/mzML/20210525_Preblank1.mzML:scan:37',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000094118',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4930137},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000081731:ccms_peak/170829_Irina_Pseudo_nitzschia_posMSMS/Pn_subpacifica_A_Unfil_II.mzML:scan:398',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000081731',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 2584971},
#   {'Delta Mass': 0.0,
#    'USI': 'mzspec:MSV000080562:peak/170220_DOM_V-opti_MS1_MSMS/mzxml/1L1g_B_MSMS.mzXML:scan:261',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000080562',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 3003717},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_234.mzML:scan:855',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4783701},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000090897:raw/mzml_files/20211028_AG_QZ_ECRP_HostBSC_20210301_Exp1_Ag683775-924_USHXG01601_POS_MSMS_129_exudate-cocult-BR-BSC13-MS_3__383.mzML:scan:345',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000090897',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 6667340},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_231r.mzML:scan:378',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4784603},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/MO23S_001r.mzML:scan:442',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4803998},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_081.mzML:scan:427',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4805477},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_233.mzML:scan:839',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4794569},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MTBLS417:FILES/CS58504_pos_IDA.mzXML:scan:4679',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MTBLS417',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 7300087},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:ST001861:20190525_Indranil_pos_spme_meta6_1.mzML:scan:9793',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'ST001861',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 6904677},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:ST001861:20190525_Indranil_pos_spme_meta7_1.mzML:scan:11468',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'ST001861',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 6907264},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000098454:peak/liangtro/MS2_20.mzML:scan:3768',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000098454',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 1215919},
#   {'Delta Mass': 0.02,
#    'USI': 'mzspec:MSV000092820:raw/083123_Matthaei_Herbarium_lowmz/2020_Matthaei_EA_150-450mz/Crassula-argentea-Leaf-ethylacetate-2020.mzML:scan:125',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000092820',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 794916},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000098454:peak/liangtro/MS2_7.mzML:scan:2955',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000098454',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 1214086},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/MO23S_072r.mzML:scan:351',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4791584},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000089289:peak/294_MT_CCE21.mzML:scan:443',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000089289',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 3247966},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_228r.mzML:scan:398',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4785907},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:ST001861:20190525_Indranil_pos_spme_meta4_3.mzML:scan:12415',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'ST001861',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 6902307},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MTBLS10526:FILES/DERIVED_FILES/FA14_72.mzML:scan:30351',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MTBLS10526',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 7522380},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:ST001861:20190525_Indranil_pos_spme_meta7_3.mzML:scan:12483',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'ST001861',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 6906678},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000089285:peak/102_MT_PB.mzML:scan:486',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000089285',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 6290541},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:ST001861:20190525_Indranil_pos_spme_meta1_1.mzML:scan:10037',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'ST001861',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 6899372},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MTBLS10526:FILES/DERIVED_FILES/FAB6b.mzML:scan:30254',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MTBLS10526',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 7522414},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000085870:peak/peak/CS58504_pos_IDA.mzXML:scan:4679',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000085870',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 2372662},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MTBLS10526:FILES/DERIVED_FILES/FA19.mzML:scan:30645',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MTBLS10526',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 7522568},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000081731:ccms_peak/170829_Irina_Pseudo_nitzschia_posMSMS/Pn_multiseries_A_DOM_II.mzML:scan:397',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000081731',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 2584880},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MTBLS10526:FILES/DERIVED_FILES/FAB3b.mzML:scan:29779',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MTBLS10526',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 7522428},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_202r.mzML:scan:365',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4790384},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000089285:ccms_peak/102_MT_PB.mzML:scan:486',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000089285',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 6290770},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_215r.mzML:scan:312',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4801748},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000098454:ccms_peak/liangtro/MS2_20.mzML:scan:3768',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000098454',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 1215084},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000090798:peak/mzml_pos/Mutant_pos_mzml/std2_7_21.mzML:scan:778',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000090798',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 477334},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MTBLS10526:FILES/DERIVED_FILES/FA3.mzML:scan:30145',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MTBLS10526',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 7522332},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:ST001861:20190525_Indranil_pos_spme_meta4_2.mzML:scan:12256',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'ST001861',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 6901111},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MTBLS10526:FILES/DERIVED_FILES/FA12a_72.mzML:scan:29882',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MTBLS10526',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 7522488},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000089289:peak/230_MT_CCE21.mzML:scan:373',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000089289',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 3247540},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000089289:ccms_peak/230_MT_CCE21.mzML:scan:373',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000089289',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 3246422},
#   {'Delta Mass': 0.01,
#    'USI': 'mzspec:MSV000080559:ccms_peak/mzxml/I_4.mzXML:scan:302',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000080559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 2233670},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000083631:peak/PEAKS/O1903325.mzXML:scan:232',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000083631',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 2469531},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000082952:ccms_peak/raw/DOM_2D_acidic_18.mzML:scan:412',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000082952',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 2677416},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MTBLS10526:FILES/DERIVED_FILES/FA6.mzML:scan:15047',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 3,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MTBLS10526',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 7522495},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_202r.mzML:scan:455',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4790387},
#   {'Delta Mass': -0.04,
#    'USI': 'mzspec:MSV000099559:peak/Moorea24_MSRun_mzml/Mo23_223.mzML:scan:1038',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000099559',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 4807040},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000081731:ccms_peak/170829_Irina_Pseudo_nitzschia_posMSMS/Pn_subpacifica_B_DOM_I.mzML:scan:424',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000081731',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 2584788},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000089289:ccms_peak/294_MT_CCE21.mzML:scan:443',
#    'Charge': 1,
#    'Cosine': 0.93,
#    'Matching Peaks': 4,
#    'Unit Delta Mass': 0,
#    'Dataset': 'MSV000089289',
#    'Status': 'NoID',
#    'Query Scan': 1,
#    'Index UnitPM': 217,
#    'Index IdxInUnitPM': 3247677},
#   {'Delta Mass': -0.03,
#    'USI': 'mzspec:MSV000098454:peak/liangtro/MS2_8.mzML:scan:2690',
#    'Charge': 1,
#    'Cosine': 0.93,
# ...
#   {'Frequency': 9, 'Dataset': 'MSV000095185', 'Unit Delta Mass': 0},
#   {'Frequency': 9, 'Dataset': 'MSV000098817', 'Unit Delta Mass': 0},
#   {'Frequency': 9, 'Dataset': 'MSV000081949', 'Unit Delta Mass': 0},
#   {'Frequency': 9, 'Dataset': 'MSV000098055', 'Unit Delta Mass': 0},
#   {'Frequency': 9, 'Dataset': 'MSV000096705', 'Unit Delta Mass': -1},
#   {'Frequency': 9, 'Dataset': 'MTBLS426', 'Unit Delta Mass': 0},
#   {'Frequency': 8, 'Dataset': 'MSV000090268', 'Unit Delta Mass': 0},
#   {'Frequency': 8, 'Dataset': 'MSV000080188', 'Unit Delta Mass': -1},
#   {'Frequency': 8, 'Dataset': 'MSV000084119', 'Unit Delta Mass': 0},
#   {'Frequency': 8, 'Dataset': 'MSV000087995', 'Unit Delta Mass': -1},
#   {'Frequency': 8, 'Dataset': 'MSV000097845', 'Unit Delta Mass': 0},
#   {'Frequency': 8, 'Dataset': 'MSV000084132', 'Unit Delta Mass': 0},
#   {'Frequency': 8, 'Dataset': 'MSV000093170', 'Unit Delta Mass': 0},
#   {'Frequency': 8, 'Dataset': 'MSV000087005', 'Unit Delta Mass': -1},
#   {'Frequency': 8, 'Dataset': 'MSV000092723', 'Unit Delta Mass': 0},
#   {'Frequency': 8, 'Dataset': 'MSV000093147', 'Unit Delta Mass': 0},
#   {'Frequency': 8, 'Dataset': 'MSV000081347', 'Unit Delta Mass': 0},
#   {'Frequency': 8, 'Dataset': 'MSV000093171', 'Unit Delta Mass': 0},
#   {'Frequency': 8, 'Dataset': 'MSV000096365', 'Unit Delta Mass': 0},
#   {'Frequency': 8, 'Dataset': 'MSV000096521', 'Unit Delta Mass': 0},
#   {'Frequency': 8, 'Dataset': 'MSV000080027', 'Unit Delta Mass': 0},
#   {'Frequency': 8, 'Dataset': 'MSV000092369', 'Unit Delta Mass': 0},
#   {'Frequency': 8, 'Dataset': 'MSV000087005', 'Unit Delta Mass': 0},
#   {'Frequency': 8, 'Dataset': 'MSV000082423', 'Unit Delta Mass': 0},
#   {'Frequency': 8, 'Dataset': 'MSV000095697', 'Unit Delta Mass': 0},
#   {'Frequency': 8, 'Dataset': 'MSV000095718', 'Unit Delta Mass': 0},
#   {'Frequency': 8, 'Dataset': 'MSV000083678', 'Unit Delta Mass': 0},
#   {'Frequency': 8, 'Dataset': 'MSV000095143', 'Unit Delta Mass': 0},
#   {'Frequency': 8, 'Dataset': 'MSV000087702', 'Unit Delta Mass': 0},
#   {'Frequency': 8, 'Dataset': 'MSV000088519', 'Unit Delta Mass': 0},
#   {'Frequency': 8, 'Dataset': 'MSV000085713', 'Unit Delta Mass': 1},
#   {'Frequency': 8, 'Dataset': 'MSV000087692', 'Unit Delta Mass': -1},
#   {'Frequency': 8, 'Dataset': 'MSV000095787', 'Unit Delta Mass': 0},
#   {'Frequency': 8, 'Dataset': 'MSV000095286', 'Unit Delta Mass': 0},
#   {'Frequency': 7, 'Dataset': 'MTBLS9914', 'Unit Delta Mass': 0},
#   {'Frequency': 7, 'Dataset': 'MSV000084744', 'Unit Delta Mass': 0},
#   {'Frequency': 7, 'Dataset': 'MSV000097771', 'Unit Delta Mass': 0},
#   {'Frequency': 7, 'Dataset': 'MSV000097963', 'Unit Delta Mass': 0},
#   {'Frequency': 7, 'Dataset': 'MSV000084741', 'Unit Delta Mass': 0},
#   {'Frequency': 7, 'Dataset': 'MSV000090129', 'Unit Delta Mass': 0},
#   {'Frequency': 7, 'Dataset': 'MSV000095905', 'Unit Delta Mass': 0},
#   {'Frequency': 7, 'Dataset': 'MSV000090304', 'Unit Delta Mass': 0},
#   {'Frequency': 7, 'Dataset': 'MTBLS8280', 'Unit Delta Mass': 0},
#   {'Frequency': 7, 'Dataset': 'MSV000096347', 'Unit Delta Mass': 1},
#   {'Frequency': 7, 'Dataset': 'MSV000090267', 'Unit Delta Mass': 0},
#   {'Frequency': 7, 'Dataset': 'MSV000098452', 'Unit Delta Mass': 0},
#   {'Frequency': 7, 'Dataset': 'MSV000081955', 'Unit Delta Mass': 0},
#   {'Frequency': 7, 'Dataset': 'MSV000094304', 'Unit Delta Mass': 0},
#   {'Frequency': 7, 'Dataset': 'MSV000088332', 'Unit Delta Mass': 0},
#   {'Frequency': 7, 'Dataset': 'MSV000083462', 'Unit Delta Mass': 0},
#   {'Frequency': 7, 'Dataset': 'MSV000080176', 'Unit Delta Mass': 0},
#   {'Frequency': 7, 'Dataset': 'MSV000083094', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'ST002956', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MSV000092926', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MSV000082821', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MSV000083263', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MSV000098584', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MSV000092323', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MSV000083264', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MSV000092338', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MSV000086012', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MSV000083888', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MSV000082391', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MSV000094264', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MSV000089552', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MSV000088534', 'Unit Delta Mass': 0},
#   {'Frequency': 6,
#    'Dataset': 'NORMAN-2405a2d5-349c-5ee1-8161-7b745bc53b43',
#    'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MSV000082608', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MSV000083632', 'Unit Delta Mass': -1},
#   {'Frequency': 6, 'Dataset': 'MSV000085025', 'Unit Delta Mass': -1},
#   {'Frequency': 6, 'Dataset': 'MSV000096328', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MSV000087711', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MSV000089821', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MSV000087861', 'Unit Delta Mass': -1},
#   {'Frequency': 6, 'Dataset': 'MSV000090851', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MTBLS2746', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MSV000082082', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MSV000096013', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MSV000086208', 'Unit Delta Mass': 1},
#   {'Frequency': 6, 'Dataset': 'MSV000086631', 'Unit Delta Mass': 1},
#   {'Frequency': 6, 'Dataset': 'MSV000086830', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MSV000090714', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MSV000088040', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MSV000090524', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MSV000095606', 'Unit Delta Mass': 0},
#   {'Frequency': 6, 'Dataset': 'MSV000088164', 'Unit Delta Mass': -1},
#   {'Frequency': 5, 'Dataset': 'MSV000085991', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'MSV000094385', 'Unit Delta Mass': -1},
#   {'Frequency': 5, 'Dataset': 'MSV000094923', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'MSV000099831', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'MTBLS5228', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'MSV000096364', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'MSV000086293', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'MSV000088842', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'MSV000097962', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'MSV000097610', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'MSV000087074', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'MSV000098584', 'Unit Delta Mass': -1},
#   {'Frequency': 5, 'Dataset': 'MSV000095712', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'MSV000095311', 'Unit Delta Mass': 1},
#   {'Frequency': 5, 'Dataset': 'MSV000090480', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'MSV000090725', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'MSV000084212', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'MTBLS916', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'MSV000085120', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'MSV000089313', 'Unit Delta Mass': -1},
#   {'Frequency': 5, 'Dataset': 'MSV000090183', 'Unit Delta Mass': -1},
#   {'Frequency': 5, 'Dataset': 'MSV000080616', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'MSV000079615', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'MSV000082073', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'MSV000079398', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'ST001912', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'ST002347', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'ST003542', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'ST001794', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'MSV000079697', 'Unit Delta Mass': -1},
#   {'Frequency': 5, 'Dataset': 'MSV000086483', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'ST003843', 'Unit Delta Mass': -1},
#   {'Frequency': 5, 'Dataset': 'MSV000086107', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'MSV000090788', 'Unit Delta Mass': 1},
#   {'Frequency': 5, 'Dataset': 'MSV000099790', 'Unit Delta Mass': 0},
#   {'Frequency': 5, 'Dataset': 'MSV000083791', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'ST002238', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000086851', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000078789', 'Unit Delta Mass': -1},
#   {'Frequency': 4, 'Dataset': 'ST004000', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000088872', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000088830', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000088829', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000080000', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000086931', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000097475', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000085359', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000082678', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'ST002844', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000081131', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'ST004186', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000088790', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000087863', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000087935', 'Unit Delta Mass': -1},
#   {'Frequency': 4, 'Dataset': 'ST003600', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000080299', 'Unit Delta Mass': 1},
#   {'Frequency': 4, 'Dataset': 'MSV000095734', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000084119', 'Unit Delta Mass': -1},
#   {'Frequency': 4, 'Dataset': 'MTBLS10129', 'Unit Delta Mass': -1},
#   {'Frequency': 4, 'Dataset': 'MSV000095406', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000097687', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000083471', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000097889', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000088682', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000092984', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000093471', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000083002', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000081432', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000083110', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000093120', 'Unit Delta Mass': -1},
#   {'Frequency': 4, 'Dataset': 'MSV000092597', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000097964', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000085119', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000098980', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000090940', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000091129', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000082261', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000096461', 'Unit Delta Mass': 0},
#   {'Frequency': 4,
#    'Dataset': 'NORMAN-7d20c4fb-64d0-4e29-bd51-331253cd5bc4',
#    'Unit Delta Mass': 0},
#   {'Frequency': 4,
#    'Dataset': 'NORMAN-28bf6572-559b-590b-89b4-492a4f9afb7b',
#    'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000081785', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000085713', 'Unit Delta Mass': -1},
#   {'Frequency': 4, 'Dataset': 'MSV000099517', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000087702', 'Unit Delta Mass': -1},
#   {'Frequency': 4, 'Dataset': 'MSV000094090', 'Unit Delta Mass': 0},
#   {'Frequency': 4, 'Dataset': 'MSV000080177', 'Unit Delta Mass': 0},
#   ...],
#  'metadata_groupings': [],
#  'log': 'bin/main_execmodule ExecIndex bin/generic_params -autoINPUT_INDEX libraries/metabolomicspanrepo_index_nightly/build_index -autoOUTPUT_RESULTS temp/queries/ad/ad13ede89d8843a192c4f703a1572a02/ad13ede89d8843a192c4f703a1572a02.tsv -autoINPUT_SPECS temp/queries/ad/ad13ede89d8843a192c4f703a1572a02/ad13ede89d8843a192c4f703a1572a02.mgf -autoPM_TOLERANCE 0.05 -autoFRAG_TOLERANCE 0.05 -autoDELTA_MZ_ABOVE 0 -autoDELTA_MZ_BELOW 0 -autoTHETA 0.7 -autoSPECTRUM_DISK_ACCESS_POLICY DISK -autoINDEX_DISK_ACCESS_POLICY DISK -autoOUTPUT_FILTERED_QUERIES_JSON_FOLDER temp/queries/ad/ad13ede89d8843a192c4f703a1572a02 -autoDELTA_F 0.4 -autoVALIDATE 0\n---\nDEBUG: /_sps/src/ExecFramework/main_execmodule.cpp : 151\nDEBUG: /_sps/src/ExecFramework/ExecSpecTagGen.cpp : 20\nDEBUG: /_sps/src/ExecFramework/ExecSpecTagGen.cpp : 20\nDEBUG: /_sps/src/ExecFramework/ExecPenaltyGen.cpp : 26\nDEBUG: /_sps/src/ExecFramework/ExecPenaltyGen.cpp : 26\nDEBUG: /_sps/src/ExecFramework/main_execmodule.cpp : 155\nDEBUG: /_sps/src/ExecFramework/main_execmodule.cpp : 166\nDEBUG: /_sps/src/ExecFramework/main_execmodule.cpp : 176: jobDoneFile = ExecIndex__results.param\nDEBUG: /_sps/src/ExecFramework/main_execmodule.cpp : 225: NORMAL EXECUTION\nDEBUG: /_sps/src/ExecFramework/main_execmodule.cpp : 226\nDEBUG: /_sps/src/proj/indexing/Index.h : 520: Index version not compatible with this binary\nDEBUG: /_sps/src/proj/indexing/Index.h : 522: Loaded processing parameters\nDEBUG: /_sps/src/proj/indexing/Index.h : 368: Size: 8342800\nDEBUG: /_sps/src/proj/indexing/Index.h : 485: Loaded filenames\nDEBUG: /_sps/src/proj/indexing/Index.h : 512: Not loading annotations in advance, will do so per-spectrum\nDEBUG: /_sps/src/ExecFramework/proj/indexing/ExecIndex.cpp : 899: Loaded 10000 bins!\nDEBUG: /_sps/src/ExecFramework/proj/indexing/ExecIndex.cpp : 1031: 100\nDEBUG: /_sps/src/ExecFramework/proj/indexing/ExecIndex.cpp : 1040: temp/queries/ad/ad13ede89d8843a192c4f703a1572a02/ad13ede89d8843a192c4f703a1572a02.mgf: 1\nDEBUG: /_sps/src/ExecFramework/proj/indexing/ExecIndex.cpp : 1055: Loaded 1 input spectra.\nDEBUG: /_sps/src/ExecFramework/main_execmodule.cpp : 235\nDEBUG: /_sps/src/ExecFramework/main_execmodule.cpp : 238: Began Invoke of: [ExecIndex] at: Thu Dec 11 22:32:03 2025\n\nDEBUG: /_sps/src/ExecFramework/proj/indexing/ExecIndex.cpp : 83: Start\nDEBUG: /_sps/src/ExecFramework/proj/indexing/ExecIndex.cpp : 733: m_params.getValueBool("REFERENCE_RUN", false) = 0\nDEBUG: /_sps/src/ExecFramework/proj/indexing/ExecIndex.cpp : 763: Running with 0.05 Da parent mass tolerance (1 index units)\nDEBUG: /_sps/src/ExecFramework/proj/indexing/ExecIndex.cpp : 764: Running with 0.05 Da fragment mass tolerance (1 index units)\nDEBUG: /_sps/src/ExecFramework/proj/indexing/ExecIndex.cpp : 793: Writing out filtered queries\nDEBUG: /_sps/src/proj/indexing/QueryRunner.h : 38: PM Range for Query Runner:0 - 10000\nDEBUG: /_sps/src/proj/indexing/QueryRunner.h : 167: Loaded: 216\nDEBUG: /_sps/src/proj/indexing/Index.h : 312: Inputting  "libraries/metabolomicspanrepo_index_nightly/build_index/216.mxc"\nDEBUG: /_sps/src/proj/indexing/QueryRunner.h : 218: temp/queries/ad/ad13ede89d8843a192c4f703a1572a02/ad13ede89d8843a192c4f703a1572a02.mgf:1 @ 217.05\nDEBUG: /_sps/src/proj/indexing/QueryRunner.h : 291: Ran in 645/206 us and 4 is the size of q (93428 us to determine candidates/35862 us for cosine) and generated 4778 true final_candidate_count (0 tp)/0 candidates in 82828/220164 list accesses out of 0 total spectra in search space searched in 0 us.\nDEBUG: /_sps/src/proj/indexing/QueryRunner.h : 312: Total reads: 9601\nDEBUG: /_sps/src/proj/indexing/QueryRunner.h : 313: Total bytes read: 1446968\nDEBUG: /_sps/src/proj/indexing/QueryRunner.h : 314: Histogram 0 1 4778 126 4572 80 0 1 2 2 10 6 2 3 13 5\nDEBUG: /_sps/src/proj/indexing/QueryRunner.h : 145: Reset: 216\nDEBUG: /_sps/src/proj/indexing/QueryRunner.h : 167: Loaded: 217\nDEBUG: /_sps/src/proj/indexing/Index.h : 312: Inputting  "libraries/metabolomicspan ...

# %%
out = []
# Out:
# 3
# 5
# 8
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File /global/common/software/m2650/msbuddy/lib/python3.8/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File /global/common/software/m2650/msbuddy/lib/python3.8/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#
# File /global/common/software/m2650/msbuddy/lib/python3.8/http/client.py:1348, in HTTPConnection.getresponse(self)
#    1347 try:
# -> 1348     response.begin()
#    1349 except ConnectionError:
#
# File /global/common/software/m2650/msbuddy/lib/python3.8/http/client.py:316, in HTTPResponse.begin(self)
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#
# File /global/common/software/m2650/msbuddy/lib/python3.8/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#
# File /global/common/software/m2650/msbuddy/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     668 try:
# --> 669     return self._sock.recv_into(b)
#     670 except timeout:
#
# File /global/common/software/m2650/msbuddy/lib/python3.8/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#
# File /global/common/software/m2650/msbuddy/lib/python3.8/ssl.py:1132, in SSLSocket.read(self, len, buffer)
#    1131 if buffer is not None:
# -> 1132     return self._sslobj.read(len, buffer)
#    1133 else:
#
# timeout: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File /global/common/software/m2650/msbuddy/lib/python3.8/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File /global/common/software/m2650/msbuddy/lib/python3.8/site-packages/urllib3/connectionpool.py:844, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     842     new_e = ProtocolError("Connection aborted.", new_e)
# --> 844 retries = retries.increment(
#     845     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     846 )
#     847 retries.sleep()
#
# File /global/common/software/m2650/msbuddy/lib/python3.8/site-packages/urllib3/util/retry.py:470, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     469 if read is False or method is None or not self._is_method_retryable(method):
# --> 470     raise reraise(type(error), error, _stacktrace)
#     471 elif read is not None:
#
# File /global/common/software/m2650/msbuddy/lib/python3.8/site-packages/urllib3/util/util.py:39, in reraise(tp, value, tb)
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#
# File /global/common/software/m2650/msbuddy/lib/python3.8/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#
# File /global/common/software/m2650/msbuddy/lib/python3.8/site-packages/urllib3/connectionpool.py:538, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     537 except (BaseSSLError, OSError) as e:
# --> 538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     539     raise
#
# File /global/common/software/m2650/msbuddy/lib/python3.8/site-packages/urllib3/connectionpool.py:370, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     369 if isinstance(err, SocketTimeout):
# --> 370     raise ReadTimeoutError(
#     371         self, url, f"Read timed out. (read timeout={timeout_value})"
#     372     ) from err
#     374 # See the above comment about EAGAIN in Python 3.
#
# ReadTimeoutError: HTTPSConnectionPool(host='fasst.gnps2.org', port=443): Read timed out. (read timeout=50)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# Cell In[31], line 5
#       3 peaks = spectra[i].T.tolist()
#       4 database_label = 'metabolomicspanrepo_index_nightly'
# ----> 5 hits = query_fasst_peaks(pmz[i], peaks, database_label, host="https://fasst.gnps2.org", analog=False, precursor_mz_tol=0.05, fragment_mz_tol=0.05, min_cos=0.7)
#       6 if len(hits['results']) > 0:
#       7     hits['envnet_index'] = i
#
# Cell In[16], line 79, in query_fasst_peaks(precursor_mz, peaks, database, host, analog, precursor_mz_tol, fragment_mz_tol, min_cos)
#      65 spectrum_query = {
#      66     "peaks": peaks,
#      67     "precursor_mz": precursor_mz
#      68 }
#      70 params = {
#      71     "query_spectrum": json.dumps(spectrum_query),
#      72     "library": database,
#    (...)
#      76     "cosine_threshold": min_cos,
#      77 }
# ---> 79 r = requests.post(os.path.join(host, "search"), data=params, timeout=50)
#      81 r.raise_for_status()
#      83 return r.json()
#
# File /global/common/software/m2650/msbuddy/lib/python3.8/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File /global/common/software/m2650/msbuddy/lib/python3.8/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /global/common/software/m2650/msbuddy/lib/python3.8/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /global/common/software/m2650/msbuddy/lib/python3.8/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /global/common/software/m2650/msbuddy/lib/python3.8/site-packages/requests/adapters.py:532, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     530     raise SSLError(e, request=request)
#     531 elif isinstance(e, ReadTimeoutError):
# --> 532     raise ReadTimeout(e, request=request)
#     533 elif isinstance(e, _InvalidHeader):
#     534     raise InvalidHeader(e, request=request)
#
# ReadTimeout: HTTPSConnectionPool(host='fasst.gnps2.org', port=443): Read timed out. (read timeout=50)

# %%
def make_spectra_for_fasst(pmz, spectra):
    spectra_list = []
    for i in range(len(pmz)):
        spec_dict = {'precursor_mz': pmz[i],
                     'spectrum': spectra[i]}
        spectra_list.append(spec_dict)
    return spectra_list
# Out:
# 22128
